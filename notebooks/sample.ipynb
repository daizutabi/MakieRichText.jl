# %%
using CairoMakie
using MakieRichText
# Out:
# [ Info: Precompiling MakieRichText [9317242e-1230-4881-bcbc-8f9566308e0e]

# %%
fig = Figure(; size=(300, 100))
ax = Axis(fig[1, 1]; title=rich(R"V_dd", R" (mV)"))
fig
